# %% [markdown]
# # Preliminary Exploratory Data Analysis (Pre-EDA)
#
# In the upcoming Preliminary Exploratory Data Analysis (Pre-EDA), we will conduct a brief examination of the available data. This process is carried out after having done a concise extract, transform and load (ETL) process to improve data quality.
# In this Pre-EDA we are going to focus on analyzing the quality of the data provided by the client in order to evaluate the way in which the data will be treated during the development of the project.

# %%
# Always Run this code

import builtin.utils as ut
# Out:
# StatementMeta(, 6ded00d1-9621-4717-bd4e-619d370d69cb, 3, Finished, Available)

# %% [markdown]
# ## 1 Memory Usage Calculation
#
# Our main objective is to make a comparisson between the amount of Gbs used into the original file and the new amount for those files in a .parquet format.
#
# This will show us how efficent our database can be by reducing his mass.

# %%
estados_size = round(ut.calculate_original_memory_usage('/lakehouse/default/Files/original/reviews-estados'), 2)
sitios_size = round(ut.calculate_original_memory_usage('/lakehouse/default/Files/original/metadata-sitios'), 2)
yelp_size = round(ut.calculate_original_memory_usage('/lakehouse/default/Files/original/Yelp'), 2)

total_size = estados_size + sitios_size + yelp_size
print(f'Total size of original data: \nEstados: {estados_size}Mb\n Sitios: {sitios_size}Mb\n Yelp: {yelp_size}Mb\n Total size: {total_size}Mb\n')

parquet_size = ut.calculate_parquet_memory_usage('/lakehouse/default/Files/df_database')
print(f'Total size of compressed data: {round(parquet_size,2)}Mb\n')

diff_size = total_size - parquet_size
print(f'Savings in resource and size usage: {round(diff_size,2)}Mb\n')

size_perc = (diff_size/total_size)*100
print(f'Percentage savings in resources: {round(size_perc,2)}%\n')
# Out:
# StatementMeta(, 6ded00d1-9621-4717-bd4e-619d370d69cb, 4, Finished, Available)
# Total size of original data:
# Estados: 24917.16Mb
#  Sitios: 2832.32Mb
#  Yelp: 8465.34Mb
#  Total size: 36214.82Mb
#
# Total size of compressed data: 10897.09Mb
#
# Savings in resource and size usage: 25317.73Mb
#
# Percentage savings in resources: 69.91%

# %% [markdown]
# ## 2. Data Quality
#
# In order to review the quality of the data, to know how we can approach our work, we carry out an inspection of each file, reviewing the data contained in each column of the tables to be studied.

# %% [markdown]
# ### 2.1 Data quality of files in the 'Metadata_sites_parquet' folder
#
# Let's apply the "data_summ" function that we have developed in "utils.py" to see the summary of the data information

# %%
folder_path = '/lakehouse/default/Files/df_database/Metadata_sitios_parquet/'

# Apply the apply_data_summ_to_parquet_folder function to get the summaries
summaries = ut.data_summ_on_parquet(folder_path)
# Out:
# StatementMeta(, 6ded00d1-9621-4717-bd4e-619d370d69cb, 5, Finished, Available)
# metadata-sitios Summary
#
# Total rows:  275001
#
# Total full null rows:  0
#           Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
#             name           [<class 'str'>, <class 'NoneType'>]       274998      0.00            3
#          address           [<class 'str'>, <class 'NoneType'>]       269428      2.03         5573
#          gmap_id                               [<class 'str'>]       275001      0.00            0
#      description           [<class 'NoneType'>, <class 'str'>]        27900     89.85       247101
#         latitude                             [<class 'float'>]       275001      0.00            0
#        longitude                             [<class 'float'>]       275001      0.00            0
#         category [<class 'numpy.ndarray'>, <class 'NoneType'>]       273662      0.49         1339
#       avg_rating                             [<class 'float'>]       275001      0.00            0
#   num_of_reviews                               [<class 'int'>]       275001      0.00            0
#            price           [<class 'NoneType'>, <class 'str'>]        31139     88.68       243862
#            hours [<class 'numpy.ndarray'>, <class 'NoneType'>]       210287     23.53        64714
#             MISC          [<class 'dict'>, <class 'NoneType'>]       221703     19.38        53298
#            state           [<class 'str'>, <class 'NoneType'>]       212960     22.56        62041
# relative_results [<class 'numpy.ndarray'>, <class 'NoneType'>]       254406      7.49        20595
#              url                               [<class 'str'>]       275001      0.00            0
# =====================================

# %% [markdown]
# ## Conclusions
#
# The previous data set shows us the following information
#
# The database has a sufficient number of records to perform an accurate analysis. In each folder we have:
# Metadata-sites:
#
# 275000 records
#
# 0 null records
#
# 7 columns containing null data; of which 5 have above 20%
#
# In another instance, during the final EDA, we will inspect the type of information in these columns in order to observe the quality of the information provided. If the information is of little relevance or is not information that can be handled with the amount of null data they have, we will proceed to eliminate it.

# %% [markdown]
# ### 2.2 Data quality of files in the 'Review_estados_parquet' folder
#
#
# Let's apply the "data_summ" function that we have developed in "utils.py" to see the summary of the data information

# %%
folder_path = '/lakehouse/default/Files/df_database/Review_estados_parquet/'

# Apply the apply_data_summ_to_parquet_folder function to get the summaries
summaries = ut.data_summ_on_parquet(folder_path)
# Out:
# StatementMeta(, 6ded00d1-9621-4717-bd4e-619d370d69cb, 6, Finished, Available)
# Alabama Summary
#
# Total rows:  1800000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1800000      0.00            0
#    name                               [<class 'str'>]      1800000      0.00            0
#    time                               [<class 'int'>]      1800000      0.00            0
#  rating                               [<class 'int'>]      1800000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       966601     46.30       833399
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        36170     97.99      1763830
#    resp          [<class 'NoneType'>, <class 'dict'>]       207283     88.48      1592717
# gmap_id                               [<class 'str'>]      1800000      0.00            0
#    date                               [<class 'str'>]      1800000      0.00            0
# =====================================
# Alaska Summary
#
# Total rows:  521515
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]       521515      0.00            0
#    name                               [<class 'str'>]       521515      0.00            0
#    time                               [<class 'int'>]       521515      0.00            0
#  rating                               [<class 'int'>]       521515      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       298257     42.81       223258
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        20851     96.00       500664
#    resp          [<class 'NoneType'>, <class 'dict'>]        44232     91.52       477283
# gmap_id                               [<class 'str'>]       521515      0.00            0
#    date                               [<class 'str'>]       521515      0.00            0
# =====================================
# Arizona Summary
#
# Total rows:  2100000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2100000      0.00            0
#    name                               [<class 'str'>]      2100000      0.00            0
#    time                               [<class 'int'>]      2100000      0.00            0
#  rating                               [<class 'int'>]      2100000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1267816     39.63       832184
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        63871     96.96      2036129
#    resp          [<class 'NoneType'>, <class 'dict'>]       339149     83.85      1760851
# gmap_id                               [<class 'str'>]      2100000      0.00            0
#    date                               [<class 'str'>]      2100000      0.00            0
# =====================================
# Arkansas Summary
#
# Total rows:  2400000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2400000      0.00            0
#    name                               [<class 'str'>]      2400000      0.00            0
#    time                               [<class 'int'>]      2400000      0.00            0
#  rating                               [<class 'int'>]      2400000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1295752     46.01      1104248
#    pics [<class 'numpy.ndarray'>, <class 'NoneType'>]        48258     97.99      2351742
#    resp          [<class 'dict'>, <class 'NoneType'>]       254783     89.38      2145217
# gmap_id                               [<class 'str'>]      2400000      0.00            0
#    date                               [<class 'str'>]      2400000      0.00            0
# =====================================
# California Summary
#
# Total rows:  2700000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2700000      0.00            0
#    name                               [<class 'str'>]      2700000      0.00            0
#    time                               [<class 'int'>]      2700000      0.00            0
#  rating                               [<class 'int'>]      2700000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1529036     43.37      1170964
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        99290     96.32      2600710
#    resp          [<class 'NoneType'>, <class 'dict'>]       245169     90.92      2454831
# gmap_id                               [<class 'str'>]      2700000      0.00            0
#    date                               [<class 'str'>]      2700000      0.00            0
# =====================================
# Colorado Summary
#
# Total rows:  2400000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2400000      0.00            0
#    name                               [<class 'str'>]      2400000      0.00            0
#    time                               [<class 'int'>]      2400000      0.00            0
#  rating                               [<class 'int'>]      2400000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1479563     38.35       920437
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        76472     96.81      2323528
#    resp          [<class 'NoneType'>, <class 'dict'>]       412135     82.83      1987865
# gmap_id                               [<class 'str'>]      2400000      0.00            0
#    date                               [<class 'str'>]      2400000      0.00            0
# =====================================
# Connecticut Summary
#
# Total rows:  2680107
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2680107      0.00            0
#    name                               [<class 'str'>]      2680107      0.00            0
#    time                               [<class 'int'>]      2680107      0.00            0
#  rating                               [<class 'int'>]      2680107      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1417301     47.12      1262806
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        70782     97.36      2609325
#    resp          [<class 'NoneType'>, <class 'dict'>]       260321     90.29      2419786
# gmap_id                               [<class 'str'>]      2680107      0.00            0
#    date                               [<class 'str'>]      2680107      0.00            0
# =====================================
# Delaware Summary
#
# Total rows:  905537
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]       905537      0.00            0
#    name                               [<class 'str'>]       905537      0.00            0
#    time                               [<class 'int'>]       905537      0.00            0
#  rating                               [<class 'int'>]       905537      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       497198     45.09       408339
#    pics [<class 'numpy.ndarray'>, <class 'NoneType'>]        19031     97.90       886506
#    resp          [<class 'NoneType'>, <class 'dict'>]        98075     89.17       807462
# gmap_id                               [<class 'str'>]       905537      0.00            0
#    date                               [<class 'str'>]       905537      0.00            0
# =====================================
# District_of_Columbia Summary
#
# Total rows:  564783
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]       564783      0.00            0
#    name                               [<class 'str'>]       564783      0.00            0
#    time                               [<class 'int'>]       564783      0.00            0
#  rating                               [<class 'int'>]       564783      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       294462     47.86       270321
#    pics [<class 'numpy.ndarray'>, <class 'NoneType'>]        29355     94.80       535428
#    resp          [<class 'NoneType'>, <class 'dict'>]        41682     92.62       523101
# gmap_id                               [<class 'str'>]       564783      0.00            0
#    date                               [<class 'str'>]       564783      0.00            0
# =====================================
# Florida Summary
#
# Total rows:  2850000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2850000      0.00            0
#    name                               [<class 'str'>]      2850000      0.00            0
#    time                               [<class 'int'>]      2850000      0.00            0
#  rating                               [<class 'int'>]      2850000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1770490     37.88      1079510
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]       104190     96.34      2745810
#    resp          [<class 'dict'>, <class 'NoneType'>]       455399     84.02      2394601
# gmap_id                               [<class 'str'>]      2850000      0.00            0
#    date                               [<class 'str'>]      2850000      0.00            0
# =====================================
# Georgia Summary
#
# Total rows:  1950000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1950000      0.00            0
#    name                               [<class 'str'>]      1950000      0.00            0
#    time                               [<class 'int'>]      1950000      0.00            0
#  rating                               [<class 'int'>]      1950000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1149497     41.05       800503
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        52839     97.29      1897161
#    resp          [<class 'NoneType'>, <class 'dict'>]       289042     85.18      1660958
# gmap_id                               [<class 'str'>]      1950000      0.00            0
#    date                               [<class 'str'>]      1950000      0.00            0
# =====================================
# Hawaii Summary
#
# Total rows:  1504347
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1504347      0.00            0
#    name                               [<class 'str'>]      1504347      0.00            0
#    time                               [<class 'int'>]      1504347      0.00            0
#  rating                               [<class 'int'>]      1504347      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       852596     43.32       651751
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]       132702     91.18      1371645
#    resp          [<class 'NoneType'>, <class 'dict'>]       108799     92.77      1395548
# gmap_id                               [<class 'str'>]      1504347      0.00            0
#    date                               [<class 'str'>]      1504347      0.00            0
# =====================================
# Idaho Summary
#
# Total rows:  2085487
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2085487      0.00            0
#    name                               [<class 'str'>]      2085487      0.00            0
#    time                               [<class 'int'>]      2085487      0.00            0
#  rating                               [<class 'int'>]      2085487      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1189843     42.95       895644
#    pics [<class 'numpy.ndarray'>, <class 'NoneType'>]        50182     97.59      2035305
#    resp          [<class 'NoneType'>, <class 'dict'>]       293130     85.94      1792357
# gmap_id                               [<class 'str'>]      2085487      0.00            0
#    date                               [<class 'str'>]      2085487      0.00            0
# =====================================
# Illinois Summary
#
# Total rows:  2100000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2100000      0.00            0
#    name                               [<class 'str'>]      2100000      0.00            0
#    time                               [<class 'int'>]      2100000      0.00            0
#  rating                               [<class 'int'>]      2100000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1187782     43.44       912218
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        58374     97.22      2041626
#    resp          [<class 'NoneType'>, <class 'dict'>]       255119     87.85      1844881
# gmap_id                               [<class 'str'>]      2100000      0.00            0
#    date                               [<class 'str'>]      2100000      0.00            0
# =====================================
# Indiana Summary
#
# Total rows:  2250000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2250000      0.00            0
#    name                               [<class 'str'>]      2250000      0.00            0
#    time                               [<class 'int'>]      2250000      0.00            0
#  rating                               [<class 'int'>]      2250000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1240490     44.87      1009510
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        47274     97.90      2202726
#    resp          [<class 'dict'>, <class 'NoneType'>]       278942     87.60      1971058
# gmap_id                               [<class 'str'>]      2250000      0.00            0
#    date                               [<class 'str'>]      2250000      0.00            0
# =====================================
# Iowa Summary
#
# Total rows:  2677684
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2677684      0.00            0
#    name                               [<class 'str'>]      2677684      0.00            0
#    time                               [<class 'int'>]      2677684      0.00            0
#  rating                               [<class 'int'>]      2677684      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1382508     48.37      1295176
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        48150     98.20      2629534
#    resp          [<class 'dict'>, <class 'NoneType'>]       268742     89.96      2408942
# gmap_id                               [<class 'str'>]      2677684      0.00            0
#    date                               [<class 'str'>]      2677684      0.00            0
# =====================================
# Kansas Summary
#
# Total rows:  1950000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1950000      0.00            0
#    name                               [<class 'str'>]      1950000      0.00            0
#    time                               [<class 'int'>]      1950000      0.00            0
#  rating                               [<class 'int'>]      1950000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1049396     46.18       900604
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        38154     98.04      1911846
#    resp          [<class 'NoneType'>, <class 'dict'>]       233500     88.03      1716500
# gmap_id                               [<class 'str'>]      1950000      0.00            0
#    date                               [<class 'str'>]      1950000      0.00            0
# =====================================
# Kentucky Summary
#
# Total rows:  1650000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1650000      0.00            0
#    name                               [<class 'str'>]      1650000      0.00            0
#    time                               [<class 'int'>]      1650000      0.00            0
#  rating                               [<class 'int'>]      1650000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       893180     45.87       756820
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        32564     98.03      1617436
#    resp          [<class 'NoneType'>, <class 'dict'>]       194501     88.21      1455499
# gmap_id                               [<class 'str'>]      1650000      0.00            0
#    date                               [<class 'str'>]      1650000      0.00            0
# =====================================
# Louisiana Summary
#
# Total rows:  1500000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1500000      0.00            0
#    name                               [<class 'str'>]      1500000      0.00            0
#    time                               [<class 'int'>]      1500000      0.00            0
#  rating                               [<class 'int'>]      1500000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       789116     47.39       710884
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        35628     97.62      1464372
#    resp          [<class 'dict'>, <class 'NoneType'>]       160140     89.32      1339860
# gmap_id                               [<class 'str'>]      1500000      0.00            0
#    date                               [<class 'str'>]      1500000      0.00            0
# =====================================
# Maine Summary
#
# Total rows:  1123881
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1123881      0.00            0
#    name                               [<class 'str'>]      1123881      0.00            0
#    time                               [<class 'int'>]      1123881      0.00            0
#  rating                               [<class 'int'>]      1123881      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       614200     45.35       509681
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        32185     97.14      1091696
#    resp          [<class 'NoneType'>, <class 'dict'>]        95831     91.47      1028050
# gmap_id                               [<class 'str'>]      1123881      0.00            0
#    date                               [<class 'str'>]      1123881      0.00            0
# =====================================
# Maryland Summary
#
# Total rows:  2400000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2400000      0.00            0
#    name                               [<class 'str'>]      2400000      0.00            0
#    time                               [<class 'int'>]      2400000      0.00            0
#  rating                               [<class 'int'>]      2400000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1326475     44.73      1073525
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        63443     97.36      2336557
#    resp          [<class 'NoneType'>, <class 'dict'>]       304365     87.32      2095635
# gmap_id                               [<class 'str'>]      2400000      0.00            0
#    date                               [<class 'str'>]      2400000      0.00            0
# =====================================
# Massachusetts Summary
#
# Total rows:  2400000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2400000      0.00            0
#    name                               [<class 'str'>]      2400000      0.00            0
#    time                               [<class 'int'>]      2400000      0.00            0
#  rating                               [<class 'int'>]      2400000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1271930     47.00      1128070
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        69498     97.10      2330502
#    resp          [<class 'NoneType'>, <class 'dict'>]       216137     90.99      2183863
# gmap_id                               [<class 'str'>]      2400000      0.00            0
#    date                               [<class 'str'>]      2400000      0.00            0
# =====================================
# Michigan Summary
#
# Total rows:  2250000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2250000      0.00            0
#    name                               [<class 'str'>]      2250000      0.00            0
#    time                               [<class 'int'>]      2250000      0.00            0
#  rating                               [<class 'int'>]      2250000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1303806     42.05       946194
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        53758     97.61      2196242
#    resp          [<class 'dict'>, <class 'NoneType'>]       304465     86.47      1945535
# gmap_id                               [<class 'str'>]      2250000      0.00            0
#    date                               [<class 'str'>]      2250000      0.00            0
# =====================================
# Minnesota Summary
#
# Total rows:  1800000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1800000      0.00            0
#    name                               [<class 'str'>]      1800000      0.00            0
#    time                               [<class 'int'>]      1800000      0.00            0
#  rating                               [<class 'int'>]      1800000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1021410     43.26       778590
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        48731     97.29      1751269
#    resp          [<class 'dict'>, <class 'NoneType'>]       236933     86.84      1563067
# gmap_id                               [<class 'str'>]      1800000      0.00            0
#    date                               [<class 'str'>]      1800000      0.00            0
# =====================================
# Mississippi Summary
#
# Total rows:  1971181
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1971181      0.00            0
#    name                               [<class 'str'>]      1971181      0.00            0
#    time                               [<class 'int'>]      1971181      0.00            0
#  rating                               [<class 'int'>]      1971181      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1025301     47.99       945880
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        33923     98.28      1937258
#    resp          [<class 'NoneType'>, <class 'dict'>]       187453     90.49      1783728
# gmap_id                               [<class 'str'>]      1971181      0.00            0
#    date                               [<class 'str'>]      1971181      0.00            0
# =====================================
# Missouri Summary
#
# Total rows:  1650000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1650000      0.00            0
#    name                               [<class 'str'>]      1650000      0.00            0
#    time                               [<class 'int'>]      1650000      0.00            0
#  rating                               [<class 'int'>]      1650000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       952732     42.26       697268
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        39723     97.59      1610277
#    resp          [<class 'NoneType'>, <class 'dict'>]       230759     86.01      1419241
# gmap_id                               [<class 'str'>]      1650000      0.00            0
#    date                               [<class 'str'>]      1650000      0.00            0
# =====================================
# Montana Summary
#
# Total rows:  950370
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]       950370      0.00            0
#    name                               [<class 'str'>]       950370      0.00            0
#    time                               [<class 'int'>]       950370      0.00            0
#  rating                               [<class 'int'>]       950370      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       531657     44.06       418713
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        20730     97.82       929640
#    resp          [<class 'NoneType'>, <class 'dict'>]       109485     88.48       840885
# gmap_id                               [<class 'str'>]       950370      0.00            0
#    date                               [<class 'str'>]       950370      0.00            0
# =====================================
# Nebraska Summary
#
# Total rows:  1817866
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1817866      0.00            0
#    name                               [<class 'str'>]      1817866      0.00            0
#    time                               [<class 'int'>]      1817866      0.00            0
#  rating                               [<class 'int'>]      1817866      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       947775     47.86       870091
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        34691     98.09      1783175
#    resp          [<class 'NoneType'>, <class 'dict'>]       209443     88.48      1608423
# gmap_id                               [<class 'str'>]      1817866      0.00            0
#    date                               [<class 'str'>]      1817866      0.00            0
# =====================================
# Nevada Summary
#
# Total rows:  1800000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1800000      0.00            0
#    name                               [<class 'str'>]      1800000      0.00            0
#    time                               [<class 'int'>]      1800000      0.00            0
#  rating                               [<class 'int'>]      1800000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1064853     40.84       735147
#    pics [<class 'numpy.ndarray'>, <class 'NoneType'>]        67318     96.26      1732682
#    resp          [<class 'NoneType'>, <class 'dict'>]       224929     87.50      1575071
# gmap_id                               [<class 'str'>]      1800000      0.00            0
#    date                               [<class 'str'>]      1800000      0.00            0
# =====================================
# New_Hampshire Summary
#
# Total rows:  1296603
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1296603      0.00            0
#    name                               [<class 'str'>]      1296603      0.00            0
#    time                               [<class 'int'>]      1296603      0.00            0
#  rating                               [<class 'int'>]      1296603      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       712107     45.08       584496
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        32336     97.51      1264267
#    resp          [<class 'NoneType'>, <class 'dict'>]       132499     89.78      1164104
# gmap_id                               [<class 'str'>]      1296603      0.00            0
#    date                               [<class 'str'>]      1296603      0.00            0
# =====================================
# New_Jersey Summary
#
# Total rows:  1950000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1950000      0.00            0
#    name                               [<class 'str'>]      1950000      0.00            0
#    time                               [<class 'int'>]      1950000      0.00            0
#  rating                               [<class 'int'>]      1950000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1085664     44.32       864336
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        55847     97.14      1894153
#    resp          [<class 'NoneType'>, <class 'dict'>]       221236     88.65      1728764
# gmap_id                               [<class 'str'>]      1950000      0.00            0
#    date                               [<class 'str'>]      1950000      0.00            0
# =====================================
# New_Mexico Summary
#
# Total rows:  1800000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1800000      0.00            0
#    name                               [<class 'str'>]      1800000      0.00            0
#    time                               [<class 'int'>]      1800000      0.00            0
#  rating                               [<class 'int'>]      1800000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1012220     43.77       787780
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        41792     97.68      1758208
#    resp          [<class 'dict'>, <class 'NoneType'>]       217741     87.90      1582259
# gmap_id                               [<class 'str'>]      1800000      0.00            0
#    date                               [<class 'str'>]      1800000      0.00            0
# =====================================
# New_York Summary
#
# Total rows:  2700000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2700000      0.00            0
#    name                               [<class 'str'>]      2700000      0.00            0
#    time                               [<class 'int'>]      2700000      0.00            0
#  rating                               [<class 'int'>]      2700000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1536407     43.10      1163593
#    pics [<class 'numpy.ndarray'>, <class 'NoneType'>]       101656     96.23      2598344
#    resp          [<class 'NoneType'>, <class 'dict'>]       263997     90.22      2436003
# gmap_id                               [<class 'str'>]      2700000      0.00            0
#    date                               [<class 'str'>]      2700000      0.00            0
# =====================================
# North_Carolina Summary
#
# Total rows:  2250000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2250000      0.00            0
#    name                               [<class 'str'>]      2250000      0.00            0
#    time                               [<class 'int'>]      2250000      0.00            0
#  rating                               [<class 'int'>]      2250000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1310439     41.76       939561
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        60493     97.31      2189507
#    resp          [<class 'NoneType'>, <class 'dict'>]       335544     85.09      1914456
# gmap_id                               [<class 'str'>]      2250000      0.00            0
#    date                               [<class 'str'>]      2250000      0.00            0
# =====================================
# North_Dakota Summary
#
# Total rows:  563693
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]       563693      0.00            0
#    name                               [<class 'str'>]       563693      0.00            0
#    time                               [<class 'int'>]       563693      0.00            0
#  rating                               [<class 'int'>]       563693      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       287695     48.96       275998
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]         9300     98.35       554393
#    resp          [<class 'NoneType'>, <class 'dict'>]        82994     85.28       480699
# gmap_id                               [<class 'str'>]       563693      0.00            0
#    date                               [<class 'str'>]       563693      0.00            0
# =====================================
# Ohio Summary
#
# Total rows:  1950000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1950000      0.00            0
#    name                               [<class 'str'>]      1950000      0.00            0
#    time                               [<class 'int'>]      1950000      0.00            0
#  rating                               [<class 'int'>]      1950000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1094959     43.85       855041
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        44741     97.71      1905259
#    resp          [<class 'dict'>, <class 'NoneType'>]       275172     85.89      1674828
# gmap_id                               [<class 'str'>]      1950000      0.00            0
#    date                               [<class 'str'>]      1950000      0.00            0
# =====================================
# Oklahoma Summary
#
# Total rows:  1650000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1650000      0.00            0
#    name                               [<class 'str'>]      1650000      0.00            0
#    time                               [<class 'int'>]      1650000      0.00            0
#  rating                               [<class 'int'>]      1650000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       935257     43.32       714743
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        34795     97.89      1615205
#    resp          [<class 'NoneType'>, <class 'dict'>]       218812     86.74      1431188
# gmap_id                               [<class 'str'>]      1650000      0.00            0
#    date                               [<class 'str'>]      1650000      0.00            0
# =====================================
# Oregon Summary
#
# Total rows:  2250000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2250000      0.00            0
#    name                               [<class 'str'>]      2250000      0.00            0
#    time                               [<class 'int'>]      2250000      0.00            0
#  rating                               [<class 'int'>]      2250000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1352875     39.87       897125
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        77096     96.57      2172904
#    resp          [<class 'NoneType'>, <class 'dict'>]       270265     87.99      1979735
# gmap_id                               [<class 'str'>]      2250000      0.00            0
#    date                               [<class 'str'>]      2250000      0.00            0
# =====================================
# Pennsylvania Summary
#
# Total rows:  2400000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2400000      0.00            0
#    name                               [<class 'str'>]      2400000      0.00            0
#    time                               [<class 'int'>]      2400000      0.00            0
#  rating                               [<class 'int'>]      2400000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1358614     43.39      1041386
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        57810     97.59      2342190
#    resp          [<class 'NoneType'>, <class 'dict'>]       300111     87.50      2099889
# gmap_id                               [<class 'str'>]      2400000      0.00            0
#    date                               [<class 'str'>]      2400000      0.00            0
# =====================================
# Rhode_Island Summary
#
# Total rows:  890006
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]       890006      0.00            0
#    name                               [<class 'str'>]       890006      0.00            0
#    time                               [<class 'int'>]       890006      0.00            0
#  rating                               [<class 'int'>]       890006      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       464261     47.84       425745
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        22547     97.47       867459
#    resp          [<class 'dict'>, <class 'NoneType'>]        77022     91.35       812984
# gmap_id                               [<class 'str'>]       890006      0.00            0
#    date                               [<class 'str'>]       890006      0.00            0
# =====================================
# South_Carolina Summary
#
# Total rows:  2100000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2100000      0.00            0
#    name                               [<class 'str'>]      2100000      0.00            0
#    time                               [<class 'int'>]      2100000      0.00            0
#  rating                               [<class 'int'>]      2100000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1189045     43.38       910955
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        51969     97.53      2048031
#    resp          [<class 'NoneType'>, <class 'dict'>]       282501     86.55      1817499
# gmap_id                               [<class 'str'>]      2100000      0.00            0
#    date                               [<class 'str'>]      2100000      0.00            0
# =====================================
# South_Dakota Summary
#
# Total rows:  673048
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]       673048      0.00            0
#    name                               [<class 'str'>]       673048      0.00            0
#    time                               [<class 'int'>]       673048      0.00            0
#  rating                               [<class 'int'>]       673048      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       347082     48.43       325966
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        15815     97.65       657233
#    resp          [<class 'NoneType'>, <class 'dict'>]        83208     87.64       589840
# gmap_id                               [<class 'str'>]       673048      0.00            0
#    date                               [<class 'str'>]       673048      0.00            0
# =====================================
# Tennessee Summary
#
# Total rows:  1800000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1800000      0.00            0
#    name                               [<class 'str'>]      1800000      0.00            0
#    time                               [<class 'int'>]      1800000      0.00            0
#  rating                               [<class 'int'>]      1800000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1020957     43.28       779043
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        43792     97.57      1756208
#    resp          [<class 'dict'>, <class 'NoneType'>]       254777     85.85      1545223
# gmap_id                               [<class 'str'>]      1800000      0.00            0
#    date                               [<class 'str'>]      1800000      0.00            0
# =====================================
# Texas Summary
#
# Total rows:  2296824
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      2296824      0.00            0
#    name                               [<class 'str'>]      2296824      0.00            0
#    time                               [<class 'int'>]      2296824      0.00            0
#  rating                               [<class 'int'>]      2296824      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1377615     40.02       919209
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        68309     97.03      2228515
#    resp          [<class 'NoneType'>, <class 'dict'>]       374838     83.68      1921986
# gmap_id                               [<class 'str'>]      2296824      0.00            0
#    date                               [<class 'str'>]      2296824      0.00            0
# =====================================
# Utah Summary
#
# Total rows:  1500000
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1500000      0.00            0
#    name                               [<class 'str'>]      1500000      0.00            0
#    time                               [<class 'int'>]      1500000      0.00            0
#  rating                               [<class 'int'>]      1500000      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       935940     37.60       564060
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        49380     96.71      1450620
#    resp          [<class 'NoneType'>, <class 'dict'>]       251615     83.23      1248385
# gmap_id                               [<class 'str'>]      1500000      0.00            0
#    date                               [<class 'str'>]      1500000      0.00            0
# =====================================
# Vermont Summary
#
# Total rows:  324725
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]       324725      0.00            0
#    name                               [<class 'str'>]       324725      0.00            0
#    time                               [<class 'int'>]       324725      0.00            0
#  rating                               [<class 'int'>]       324725      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       178168     45.13       146557
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]         9651     97.03       315074
#    resp          [<class 'dict'>, <class 'NoneType'>]        26838     91.74       297887
# gmap_id                               [<class 'str'>]       324725      0.00            0
#    date                               [<class 'str'>]       324725      0.00            0
# =====================================
# Virginia Summary
#
# Total rows:  1662059
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1662059      0.00            0
#    name                               [<class 'str'>]      1662059      0.00            0
#    time                               [<class 'int'>]      1662059      0.00            0
#  rating                               [<class 'int'>]      1662059      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       949191     42.89       712868
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        46039     97.23      1616020
#    resp          [<class 'NoneType'>, <class 'dict'>]       224819     86.47      1437240
# gmap_id                               [<class 'str'>]      1662059      0.00            0
#    date                               [<class 'str'>]      1662059      0.00            0
# =====================================
# Washington Summary
#
# Total rows:  1942020
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1942020      0.00            0
#    name                               [<class 'str'>]      1942020      0.00            0
#    time                               [<class 'int'>]      1942020      0.00            0
#  rating                               [<class 'int'>]      1942020      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]      1147921     40.89       794099
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        74860     96.15      1867160
#    resp          [<class 'NoneType'>, <class 'dict'>]       223824     88.47      1718196
# gmap_id                               [<class 'str'>]      1942020      0.00            0
#    date                               [<class 'str'>]      1942020      0.00            0
# =====================================
# West_Virginia Summary
#
# Total rows:  1080333
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1080333      0.00            0
#    name                               [<class 'str'>]      1080333      0.00            0
#    time                               [<class 'int'>]      1080333      0.00            0
#  rating                               [<class 'int'>]      1080333      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       559223     48.24       521110
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        18588     98.28      1061745
#    resp          [<class 'NoneType'>, <class 'dict'>]        93149     91.38       987184
# gmap_id                               [<class 'str'>]      1080333      0.00            0
#    date                               [<class 'str'>]      1080333      0.00            0
# =====================================
# Wisconsin Summary
#
# Total rows:  1686482
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]      1686482      0.00            0
#    name                               [<class 'str'>]      1686482      0.00            0
#    time                               [<class 'int'>]      1686482      0.00            0
#  rating                               [<class 'int'>]      1686482      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       937290     44.42       749192
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        39925     97.63      1646557
#    resp          [<class 'NoneType'>, <class 'dict'>]       214240     87.30      1472242
# gmap_id                               [<class 'str'>]      1686482      0.00            0
#    date                               [<class 'str'>]      1686482      0.00            0
# =====================================
# Wyoming Summary
#
# Total rows:  427808
#
# Total full null rows:  0
#  Column                                     Data_type  No_miss_Qty  %Missing  Missing_Qty
# user_id                             [<class 'float'>]       427808      0.00            0
#    name                               [<class 'str'>]       427808      0.00            0
#    time                               [<class 'int'>]       427808      0.00            0
#  rating                               [<class 'int'>]       427808      0.00            0
#    text           [<class 'str'>, <class 'NoneType'>]       234662     45.15       193146
#    pics [<class 'NoneType'>, <class 'numpy.ndarray'>]        10801     97.48       417007
#    resp          [<class 'NoneType'>, <class 'dict'>]        43965     89.72       383843
# gmap_id                               [<class 'str'>]       427808      0.00            0
#    date                               [<class 'str'>]       427808      0.00            0
# =====================================

# %% [markdown]
# ## Conclusions
# The previous data set shows us the following information
#
# Reviews-states:
#
# 51 files which have between 300 thousand and 2.8 million records
#
# 0 null records
#
# 3 columns have over 35% null data; the same for all files
#
# In another instance, during the final EDA, we will inspect the type of information in these columns in order to observe the quality of the information provided. If the information is of little relevance or is not information that can be handled with the amount of null data they have, we will proceed to eliminate it.

# %% [markdown]
# ### 2.3 Data quality of files in the 'Yelp_parquet' folder
#
#
# Let's apply the "data_summ" function that we have developed in "utils.py" to see the summary of the data information

# %%
folder_path = '/lakehouse/default/Files/df_database/Yelp_parquet/'

# Apply the apply_data_summ_to_parquet_folder function to get the summaries
summaries = ut.data_summ_on_parquet(folder_path)
# Out:
# StatementMeta(, 6ded00d1-9621-4717-bd4e-619d370d69cb, 7, Finished, Available)
# business.pkl Summary
#
# Total rows:  150346
#
# Total full null rows:  0
#       Column                            Data_type  No_miss_Qty  %Missing  Missing_Qty
#  business_id                      [<class 'str'>]       150346      0.00            0
#         name                      [<class 'str'>]       150346      0.00            0
#      address                      [<class 'str'>]       150346      0.00            0
#         city                      [<class 'str'>]       150346      0.00            0
#        state  [<class 'NoneType'>, <class 'str'>]       150343      0.00            3
#  postal_code                      [<class 'str'>]       150346      0.00            0
#     latitude                    [<class 'float'>]       150346      0.00            0
#    longitude                    [<class 'float'>]       150346      0.00            0
#        stars                    [<class 'float'>]       150346      0.00            0
# review_count                      [<class 'int'>]       150346      0.00            0
#      is_open                      [<class 'int'>]       150346      0.00            0
#   attributes [<class 'dict'>, <class 'NoneType'>]       136602      9.14        13744
#   categories  [<class 'str'>, <class 'NoneType'>]       150243      0.07          103
#        hours [<class 'NoneType'>, <class 'dict'>]       127123     15.45        23223
# =====================================
# checkin.json Summary
#
# Total rows:  131930
#
# Total full null rows:  0
#      Column       Data_type  No_miss_Qty  %Missing  Missing_Qty
# business_id [<class 'str'>]       131930       0.0            0
#        date [<class 'str'>]       131930       0.0            0
# =====================================
# review.json Summary
#
# Total rows:  6990280
#
# Total full null rows:  0
#      Column                                            Data_type  No_miss_Qty  %Missing  Missing_Qty
#   review_id                                      [<class 'str'>]      6990280       0.0            0
#     user_id                                      [<class 'str'>]      6990280       0.0            0
# business_id                                      [<class 'str'>]      6990280       0.0            0
#       stars                                      [<class 'int'>]      6990280       0.0            0
#      useful                                      [<class 'int'>]      6990280       0.0            0
#       funny                                      [<class 'int'>]      6990280       0.0            0
#        cool                                      [<class 'int'>]      6990280       0.0            0
#        text                                      [<class 'str'>]      6990280       0.0            0
#        date [<class 'pandas._libs.tslibs.timestamps.Timestamp'>]      6990280       0.0            0
# =====================================
# tip.json Summary
#
# Total rows:  908915
#
# Total full null rows:  0
#           Column                                            Data_type  No_miss_Qty  %Missing  Missing_Qty
#          user_id                                      [<class 'str'>]       908915       0.0            0
#      business_id                                      [<class 'str'>]       908915       0.0            0
#             text                                      [<class 'str'>]       908915       0.0            0
#             date [<class 'pandas._libs.tslibs.timestamps.Timestamp'>]       908915       0.0            0
# compliment_count                                      [<class 'int'>]       908915       0.0            0
# =====================================
# user Summary
#
# Total rows:  908915
#
# Total full null rows:  0
#           Column                                            Data_type  No_miss_Qty  %Missing  Missing_Qty
#          user_id                                      [<class 'str'>]       908915       0.0            0
#      business_id                                      [<class 'str'>]       908915       0.0            0
#             text                                      [<class 'str'>]       908915       0.0            0
#             date [<class 'pandas._libs.tslibs.timestamps.Timestamp'>]       908915       0.0            0
# compliment_count                                      [<class 'int'>]       908915       0.0            0
# =====================================

# %% [markdown]
# ## Conclusions
#
# The previous data set shows us the following information
#
# Yelp:
# 4 files with 9.1 million records in their entirety.
#
# 0 null records
#
# 1 file with 3 columns containing low percentage of null data
#
# In another instance, during the final EDA, we will inspect the type of information in these columns in order to observe the quality of the information provided. If the information is of little relevance or is not information that can be handled with the amount of null data they have, we will proceed to eliminate it.
